# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamagoulioti/python/blob/main/exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Φτιάξτε ένα σύνολο δεδομένων με πληροφορίες για 3 άρθρα από ένα δημοσιογραφικό site της επιλογής σας.
#
# Οι πληροφορίες για κάθε άρθρο, θα είναι:
# - τίτλος του άρθρου
# - url του άρθρου
# - συντάκτης του άρθρου
# - θεματική κατηγορία άρθρου
# - ημερομηνία δημοσίευσης του άρθρου
#
# Οι πληροφορίες για κάθε άρθρο θα τοποθετηθούν σε ένα λεξικό.
#
# Το σύνολο των δεδομένων της αρθρογραφίας των 3 άρθρων θα είναι μια λίστα, η οποία θα περιέχει τα 3 λεξικά.
#
# **Παράδειγμα λεξικού (dictionary) με πληροφορίες για ένα άρθρο**:
# ```
# articleD_1 = {
#   "title": "Συναγερμός για κρούσμα κροτωνογενούς εγκεφαλίτιδας στην Ελλάδα – Εγκύκλιος ΕΟΔΥ",
#   "url": "https://www.news247.gr/ygeia/sinagermos-gia-krousma-krotonogenous-egkefalitidas-stin-ellada-egkiklios-eodi/",
#   "author": "ΓΙΑΝΝΗΣ ΔΕΒΕΤΖΟΓΛΟΥ",
#   "section": "Υγεία",
#   "date": "27 Μαρτίου 2025 13:40"
# }
# ```
#
# **Hints & Tips:**
# - αρχικά μπορείτε να δημιουργήσετε μια κενή λίστα με όνομα π.χ. "articlesL"
# - στη συνέχεια μπορείτε να δημιουργείτε ένα-ένα τα λεξικά με τις πληροφορίες για τα άρθρα (όπως στο παραπάνω παράδειγμα) και
# - να προσθέτε ένα-ένα τα λεξικά στη λίστα με append()
# - τέλος, καλέστε τη λίστα των άρθρων με το όνομά της για να εμφανιστεί στην οθόνη (μπορείτε να την κάνετε και print για να δείτε τη διαφορά στον τρόπο που εμφανίζεται η λίστα στην οθόνη)

# %%
articlesL = []

# %%
articleD_1 = {
    "title" : "Η πλημμυρισμένη Πάρος από το διάστημα",
    "url" : "https://www.kathimerini.gr/society/563543371/i-plimmyrismeni-paros-apo-to-diastima/" ,
    "author" : "Καθημερινή" ,
    "section" : "Κοινωνία" ,
    "date" :  "1 Απριλίου 2025 10:00"
}

# %%
articleD_2 = {
    "title" : "Μεγάλη φωτιά τώρα στα Άνω Πατήσια - Συναγερμός στην Πυροσβεστική" ,
    "url" : "https://eleftherostypos.gr/ellada/megali-fotia-tora-sta-ano-patisia-synagermos-stin-pyrosvestiki/",
    "author" : "Ελεύθερος Τύπος" ,
    "section" : "Ελλάδα" ,
    "date" : "1 Απριλίου 2025 11:30"
}

# %%
articleD_3 = {
    "title" : "Νέο έκτακτο δελτίο της ΕΜΥ - Πού θα πλήξει η κακοκαιρία τις επόμενες ώρες" ,
    "url" : "https://eleftherostypos.gr/ellada/neo-ektakto-deltio-tis-emy-pou-tha-plixei-i-kakokairia-tis-epomenes-ores-provlimata-stin-kriti-sokaristika-vinteo-apo-paro-kai-mykono/",
    "author" : "Ελεύθερος Τύπος",
    "section" : "Καιρός",
    "date" : "1 Απριλίου 2025 12:15"
}

# %%
articlesL.append(articleD_1)
articlesL.append(articleD_2)
articlesL.append(articleD_3)

# %%
print(articlesL)
# Out:
# [{'title': 'Η πλημμυρισμένη Πάρος από το διάστημα', 'url': 'https://www.kathimerini.gr/society/563543371/i-plimmyrismeni-paros-apo-to-diastima/', 'author': 'Καθημερινή', 'section': 'Κοινωνία', 'date': '1 Απριλίου 2025 10:00'}, {'title': 'Μεγάλη φωτιά τώρα στα Άνω Πατήσια - Συναγερμός στην Πυροσβεστική', 'url': 'https://eleftherostypos.gr/ellada/megali-fotia-tora-sta-ano-patisia-synagermos-stin-pyrosvestiki/', 'author': 'Ελεύθερος Τύπος', 'section': 'Ελλάδα', 'date': '1 Απριλίου 2025 11:30'}, {'title': 'Νέο έκτακτο δελτίο της ΕΜΥ - Πού θα πλήξει η κακοκαιρία τις επόμενες ώρες', 'url': 'https://eleftherostypos.gr/ellada/neo-ektakto-deltio-tis-emy-pou-tha-plixei-i-kakokairia-tis-epomenes-ores-provlimata-stin-kriti-sokaristika-vinteo-apo-paro-kai-mykono/', 'author': 'Ελεύθερος Τύπος', 'section': 'Καιρός', 'date': '1 Απριλίου 2025 12:15'}]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Μετατρέψτε τη λίστα με τα λεξικά που φτιάξατε στην προηγούμενη άσκηση σε pandas dataframe.
#
# **Hints & Tips:**
# - Εισάγετε τη βιβλιοθήκη pandas με την εντολή ```import pandas as pd```
# - Δημιουργήστε ένα dataframe με όνομα ```df```, με την εντολή ```df = pd.DataFrame(articlesL)```
# - Καλέστε το df για να εμφανιστεί στην οθόνη

# %%
import pandas as pd
articlesL = []

# %%
articleD_1 = {
    "title" : "Η πλημμυρισμένη Πάρος από το διάστημα",
    "url" : "https://www.kathimerini.gr/society/563543371/i-plimmyrismeni-paros-apo-to-diastima/",
    "author" : "Καθημερινή",
    "section" : "Κοινωνία",
    "date" : "1 Απριλίου 2025 10:00"
}

# %%
articleD_2 = {
    "title" : "Μεγάλη φωτιά τώρα στα Άνω Πατήσια - Συναγερμός στην Πυροσβεστική" ,
    "url" : "https://eleftherostypos.gr/ellada/megali-fotia-tora-sta-ano-patisia-synagermos-stin-pyrosvestiki/" ,
    "author" : "Ελεύθερος Τύπος" ,
    "section" : "Ελλάδα" ,
    "date" : "1 Απριλίου 2025 11:30"
}

# %%
articleD_3 = {
    "title" : "Νέο έκτακτο δελτίο της ΕΜΥ - Πού θα πλήξει η κακοκαιρίκα τις επόμενες ώρες" ,
    "url" : "https://eleftherostypos.gr/ellada/neo-ektakto-deltio-tis-emy-pou-tha-plixei-i-kakokairia-tis-epomenes-ores-provlimata-stin-kriti-sokaristika-vinteo-apo-paro-kai-mykono/" ,
    "author" : "Ελεύθερος Τύπος" ,
    "section" : "Καιρός" ,
    "date" : "1 Απριλίου 2025 12:15"
}

# %%
articlesL.append(articleD_1)
articlesL.append(articleD_2)
articlesL.append(articleD_3)

# %%
df = pd.DataFrame(articlesL)

# %%
print(df)
# Out:
#                                                title  \
# 0              Η πλημμυρισμένη Πάρος από το διάστημα
# 1  Μεγάλη φωτιά τώρα στα Άνω Πατήσια - Συναγερμός...
# 2  Νέο έκτακτο δελτίο της ΕΜΥ - Πού θα πλήξει η κ...
#
#                                                  url           author  \
# 0  https://www.kathimerini.gr/society/563543371/i...       Καθημερινή
# 1  https://eleftherostypos.gr/ellada/megali-fotia...  Ελεύθερος Τύπος
# 2  https://eleftherostypos.gr/ellada/neo-ektakto-...  Ελεύθερος Τύπος
#
#     section                   date
# 0  Κοινωνία  1 Απριλίου 2025 10:00
# 1    Ελλάδα  1 Απριλίου 2025 11:30
# 2    Καιρός  1 Απριλίου 2025 12:15

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
import pandas as pd

covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 471245          5740           0.0            0.0                      NaN
# 471246          5740           0.0            0.0                      NaN
# 471247          5740           0.0            0.0                      NaN
# 471248          5740           0.0            0.0                      NaN
# 471249          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 471245                       NaN  ...       2.154574             NaN
# 471246                       NaN  ...       2.154574             NaN
# 471247                       NaN  ...       2.154574             NaN
# 471248                       NaN  ...       2.154574             NaN
# 471249                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 471245                      1737.0                     1819.0
# 471246                      1738.0                     1820.0
# 471247                      1739.0                     1821.0
# 471248                      1740.0                     1822.0
# 471249                      1741.0                     1823.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 471245                                1779.0
# 471246                                1780.0
# 471247                                1781.0
# 471248                                1782.0
# 471249                                1783.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 471245                                   1819.0
# 471246                                   1820.0
# 471247                                   1821.0
# 471248                                   1822.0
# 471249                                   1823.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 471245                                 1737.0                   0.0
# 471246                                 1738.0                   0.0
# 471247                                 1739.0                   0.0
# 471248                                 1740.0                   0.0
# 471249                                 1741.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 471245                            0.0                               0.0
# 471246                            0.0                               0.0
# 471247                            0.0                               0.0
# 471248                            0.0                               0.0
# 471249                            0.0                               0.0
#
# [471250 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd
covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/vaccinations_us/vaccinations_us.csv")
covid_df
# Out:
#          state        date  total_vaccinations  total_distributed  \
# 0      Alabama  2021-01-12             78134.0           377025.0
# 1      Alabama  2021-01-13             84040.0           378975.0
# 2      Alabama  2021-01-14             92300.0           435350.0
# 3      Alabama  2021-01-15            100567.0           444650.0
# 4      Alabama  2021-01-16                 NaN                NaN
# ...        ...         ...                 ...                ...
# 54623  Wyoming  2023-05-06                 NaN                NaN
# 54624  Wyoming  2023-05-07                 NaN                NaN
# 54625  Wyoming  2023-05-08                 NaN                NaN
# 54626  Wyoming  2023-05-09                 NaN                NaN
# 54627  Wyoming  2023-05-10            854132.0          1281755.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0                70861.0                                 0.15
# 1                74792.0                                 0.19
# 2                80480.0                                  NaN
# 3                86956.0                                 0.28
# 4                    NaN                                  NaN
# ...                  ...                                  ...
# 54623                NaN                                  NaN
# 54624                NaN                                  NaN
# 54625                NaN                                  NaN
# 54626                NaN                                  NaN
# 54627           353727.0                                53.15
#
#        total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                                1.59                   7270.0
# 1                                1.71                   9245.0
# 2                                1.88                      NaN
# 3                                2.05                  13488.0
# 4                                 NaN                      NaN
# ...                               ...                      ...
# 54623                             NaN                      NaN
# 54624                             NaN                      NaN
# 54625                             NaN                      NaN
# 54626                             NaN                      NaN
# 54627                          147.58                 307619.0
#
#        people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                               1.45                     7.69
# 1                               1.53                     7.73
# 2                               1.64                     8.88
# 3                               1.77                     9.07
# 4                                NaN                      NaN
# ...                              ...                      ...
# 54623                            NaN                      NaN
# 54624                            NaN                      NaN
# 54625                            NaN                      NaN
# 54626                            NaN                      NaN
# 54627                          61.12                   221.47
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                 NaN
# 1                      5906.0              5906.0
# 2                      8260.0              7083.0
# 3                      8267.0              7478.0
# 4                         NaN              7498.0
# ...                       ...                 ...
# 54623                     NaN                77.0
# 54624                     NaN               100.0
# 54625                     NaN               123.0
# 54626                     NaN               146.0
# 54627                     NaN               170.0
#
#        daily_vaccinations_per_million  share_doses_used  total_boosters  \
# 0                                 NaN             0.207             NaN
# 1                              1205.0             0.222             NaN
# 2                              1445.0             0.212             NaN
# 3                              1525.0             0.226             NaN
# 4                              1529.0               NaN             NaN
# ...                               ...               ...             ...
# 54623                           133.0               NaN             NaN
# 54624                           173.0               NaN             NaN
# 54625                           213.0               NaN             NaN
# 54626                           252.0               NaN             NaN
# 54627                           294.0             0.666        219773.0
#
#        total_boosters_per_hundred
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 54623                         NaN
# 54624                         NaN
# 54625                         NaN
# 54626                         NaN
# 54627                       37.97
#
# [54628 rows x 16 columns]
